# %% [markdown]
# # Finetuning Object Detection with Transformers (DETR)

# %% [markdown]
# ## 1. Import packages.

# %%
import argparse
import datetime
import json
import random
import time
import os
from pathlib import Path
import matplotlib.pyplot as plt
import matplotlib.patches as patches

import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
import torchvision.transforms as T
from PIL import Image

import detr.util.misc as utils
from detr.datasets import build_dataset, get_coco_api_from_dataset
from detr.engine import evaluate, train_one_epoch
from detr.models import build_model
import detr.datasets as datasets

from opt import get_args_parser

# %% [markdown]
# ## 2. Preliminaries for PASCAL VOC dataset and visualization

# %%
# PASCAL VOC classes
CLASSES = [
    'background',
    'aeroplane',
    'bicycle',
    'bird',
    'boat',
    'bottle',
    'bus',
    'car',
    'cat',
    'chair',
    'cow',
    'diningtable',
    'dog',
    'horse',
    'motorbike',
    'person',
    'pottedplant',
    'sheep',
    'sofa',
    'train',
    'tvmonitor',
]

# colors for visualization
COLORS = [[0.000, 0.447, 0.741], [0.850, 0.325, 0.098], [0.929, 0.694, 0.125],
          [0.494, 0.184, 0.556], [0.466, 0.674, 0.188], [0.301, 0.745, 0.933]]

# standard PyTorch mean-std input image normalization
transform = T.Compose([
    T.Resize(800),
    T.ToTensor(),
    T.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# for output bounding box post-processing
def box_cxcywh_to_xyxy(x):
    x_c, y_c, w, h = x.unbind(1)
    b = [(x_c - 0.5 * w), (y_c - 0.5 * h),
         (x_c + 0.5 * w), (y_c + 0.5 * h)]
    return torch.stack(b, dim=1)

def rescale_bboxes(out_bbox, size):
    img_w, img_h = size
    b = box_cxcywh_to_xyxy(out_bbox)
    b = b * torch.tensor([img_w, img_h, img_w, img_h], dtype=torch.float32)
    return b

def plot_results(pil_img, prob, boxes):
    plt.figure(figsize=(16,10))
    plt.imshow(pil_img)
    ax = plt.gca()
    colors = COLORS * 100
    for p, (xmin, ymin, xmax, ymax), c in zip(prob, boxes.tolist(), colors):
        ax.add_patch(plt.Rectangle((xmin, ymin), xmax - xmin, ymax - ymin,
                                   fill=False, color=c, linewidth=3))
        cl = p.argmax()
        text = f'{CLASSES[cl]}: {p[cl]:0.2f}'
        ax.text(xmin, ymin, text, fontsize=15,
                bbox=dict(facecolor='yellow', alpha=0.5))
    plt.axis('off')
    plt.show()

# %% [markdown]
# ## 3. GIoU

# %%
def l2(x, y):
    return ((x - y)**2).sum() ** (1 / 2)

def bbox_iou(box1, box2):
    """
    Returns the IoU of two bounding boxes 
    box 1 : (1, 4) shaped pytorch tensors - sinlge GT bounding box
    box 2 : (N, 4) shaped pytorch tensors - multiple predictions from network
    """
    b1_x1, b1_y1, b1_x2, b1_y2 = box1[:,0], box1[:,1], box1[:,0]+box1[:,2], box1[:,1]+box1[:,3]
    b2_x1, b2_y1, b2_x2, b2_y2 = box2[:,0], box2[:,1], box2[:,0]+box2[:,2], box2[:,1]+box2[:,3]

    ## intersection rectangle coordinate
    inter_rect_x1 = torch.max(b1_x1, b2_x1)
    inter_rect_y1 = torch.max(b1_y1, b2_y1)
    inter_rect_x2 = torch.min(b1_x2, b2_x2)
    inter_rect_y2 = torch.min(b1_y2, b2_y2)

    ## intersection area
    inter_area = torch.clamp(inter_rect_x2-inter_rect_x1, min=0.)\
            * torch.clamp(inter_rect_y2-inter_rect_y1, min=0.)

    ## calculate iou
    area_1 = (b1_x2 - b1_x1) * (b1_y2 - b1_y1)
    area_2 = (b2_x2 - b2_x1) * (b2_y2 - b2_y1)
    
    union = (area_1 + area_2 - inter_area)
    iou = inter_area / union

    return iou, union

def generalized_bbox_iou(box1, box2):
    """
    """
    ## practice
    iou, union = bbox_iou(box1, box2)

    lt = torch.min(box1[:, None, :2], box2[:, :2])
    rb = torch.max(box1[:, None, 2:] + box1[:, None, :2], box2[:, 2:] + box2[:, :2])
    
    wh = (rb - lt).clamp(min=0)  # [N,M,2]
    area = wh[:, :, 0] * wh[:, :, 1]

    return iou - (area - union) / area

def draw_bb(img, boxes, color='r'):
    colors = ['r', 'b']
    fig,ax = plt.subplots(1)
    for i, box in enumerate(boxes):
        rect = patches.Rectangle(
            (box[0, 0],box[0, 1]),
            box[0, 2],
            box[0, 3],
            linewidth=3,
            edgecolor=colors[i],
            facecolor='none')
        ax.add_patch(rect)
    ax.imshow(img)

# %%
gt_box = torch.Tensor([[8, 8, 8, 8]])

boxes = [
    torch.Tensor([[6, 4, 6, 10]]),
    torch.Tensor([[3, 10, 10, 9]]),
    torch.Tensor([[4, 7, 9, 6]]),
]

img = np.ones([32, 32, 3]) * 255
img = Image.fromarray(img.astype('uint8'), 'RGB')

for box in boxes:
    iou, union = bbox_iou(gt_box, box)
    giou = generalized_bbox_iou(gt_box, box).sum()
    loss = l2(gt_box, box).sum()
    print(f'IoU: {float(iou):.2f} / loss: {float(iou):.2f} / GIoU: {float(giou):.2f} ')
    draw_bb(img, [gt_box, box])
    plt.show()
# Out:
# IoU: 0.24 / loss: 0.24 / GIoU: 0.07
# IoU: 0.24 / loss: 0.24 / GIoU: 0.11
# IoU: 0.27 / loss: 0.27 / GIoU: 0.13

# %%
def draw_bb(img, boxes, color='r'):
    fig,ax = plt.subplots(1)
    for box in boxes:
        rect = patches.Rectangle(
            (box[0],box[1]),
            box[2],
            box[3],
            linewidth=3,
            edgecolor=color,
            facecolor='none')
        ax.add_patch(rect)
    ax.imshow(img)

# %% [markdown]
# ## 4. Load PASCAL VOC Dataset.

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

parser = get_args_parser()
args = parser.parse_known_args()[0]

voc_train = build_dataset(image_set='train', args=args)
voc_val = build_dataset(image_set='val', args=args)

data_loader_train = torch.utils.data.DataLoader(
    voc_train, batch_size=1, shuffle=True, num_workers=4,
    collate_fn=utils.collate_fn)

data_loader_val = torch.utils.data.DataLoader(
    voc_val, batch_size=1, shuffle=False, num_workers=4,
    collate_fn=utils.collate_fn)

base_ds = get_coco_api_from_dataset(voc_val)
# Out:
# VOC2007
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# VOC2007
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!

# %% [markdown]
# ## 5. Finetuning pre-trained DETR on PASCAL VOC Dataset

# %% [markdown]
# ### 5-1. Define DETR and criterion.

# %%
# define model, criterion, postprocessors
model, criterion, postprocessors = build_model(args)

pretrained_url = 'https://dl.fbaipublicfiles.com/detr/detr-r50-e632da11.pth'
checkpoint = torch.hub.load_state_dict_from_url(
                pretrained_url, map_location='cpu', check_hash=True)
model.load_state_dict(checkpoint['model'])

print("DETR on COCO Dataset")
print(model.class_embed)

# replace the classifier with a new one, that has
# num_classes which is user-defined
num_classes = 21  #  class (20) + background

# get number of input features for the classifier
in_features = model.class_embed.in_features

# replace the pre-trained class_embed with a new one
model.class_embed = nn.Linear(in_features, num_classes + 1)

model.to(device)

print("DETR on PASCAL VOC Dataset")
print(model.class_embed)
# Out:
# DETR on COCO Dataset
# Linear(in_features=256, out_features=92, bias=True)
# DETR on PASCAL VOC Dataset
# Linear(in_features=256, out_features=22, bias=True)

# %% [markdown]
# ### 5-2. Define optimizier and lr scheduler.

# %%
n_parameters = sum(p.numel() for p in model.parameters() if p.requires_grad)
print('number of params:', n_parameters)

param_dicts = [
    {
        "params": [p for n, p in model.named_parameters() if "backbone" in n and p.requires_grad],
        "lr": args.lr_backbone,
    },
]

optimizer = torch.optim.AdamW(param_dicts, lr=args.lr, weight_decay=args.weight_decay)
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer, args.lr_drop)
# Out:
# number of params: 41284378

# %% [markdown]
# ### 5-3. Finetuning

# %%
epochs = 5

output_dir = Path('logs')
os.makedirs(output_dir, exist_ok=True)

start_time = time.time()
for epoch in range(epochs):
    train_stats = train_one_epoch(
        model, criterion, data_loader_train, optimizer, device, epoch,
        args.clip_max_norm)
    lr_scheduler.step()
    
    if output_dir:
        checkpoint_paths = [output_dir / 'checkpoint.pth']
        # extra checkpoint before LR drop and every 100 epochs
        if (epoch + 1) % args.lr_drop == 0 or (epoch + 1) % 100 == 0:
            checkpoint_paths.append(output_dir / f'checkpoint{epoch:04}.pth')
        for checkpoint_path in checkpoint_paths:
            utils.save_on_master({
                'model': model.state_dict(),
                'optimizer': optimizer.state_dict(),
                'lr_scheduler': lr_scheduler.state_dict(),
                'epoch': epoch,
                'args': args,
            }, checkpoint_path)

    test_stats, coco_evaluator = evaluate(
        model, criterion, postprocessors, data_loader_val, base_ds, device, output_dir
    )

    log_stats = {**{f'train_{k}': v for k, v in train_stats.items()},
                 **{f'test_{k}': v for k, v in test_stats.items()},
                 'epoch': epoch,
                 'n_parameters': n_parameters}

#     if output_dir and utils.is_main_process():
#         with (output_dir / "log.txt").open("a") as f:
#             f.write(json.dumps(log_stats) + "\n")

#     # for evaluation logs
#     if coco_evaluator is not None:
#         (output_dir / 'eval').mkdir(exist_ok=True)
#         if "bbox" in coco_evaluator.coco_eval:
#             filenames = ['latest.pth']
#             if epoch % 50 == 0:
#                 filenames.append(f'{epoch:03}.pth')
#             for name in filenames:
#                 torch.save(coco_evaluator.coco_eval["bbox"].eval,
#                                    output_dir / "eval" / name)

total_time = time.time() - start_time
total_time_str = str(datetime.timedelta(seconds=int(total_time)))
print('Training time {}'.format(total_time_str))
# Out:
# /root/code/posco_objectdetection/detr/models/position_encoding.py:41: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   dim_t = self.temperature ** (2 * (dim_t // 2) / self.num_pos_feats)
# Epoch: [0] Total time: 0:00:48 (0.1515 s / it)
# Averaged stats: lr: 0.000010  class_error: 100.00  loss: 17.6288 (19.0925)  loss_ce: 2.2517 (2.5681)  loss_bbox: 0.2748 (0.3108)  loss_giou: 0.2135 (0.2592)  loss_ce_0: 2.3283 (2.6483)  loss_bbox_0: 0.3261 (0.3601)  loss_giou_0: 0.1980 (0.2946)  loss_ce_1: 2.2416 (2.6303)  loss_bbox_1: 0.3038 (0.3322)  loss_giou_1: 0.2252 (0.2766)  loss_ce_2: 2.1706 (2.5469)  loss_bbox_2: 0.3276 (0.3275)  loss_giou_2: 0.2427 (0.2686)  loss_ce_3: 2.1886 (2.5473)  loss_bbox_3: 0.2902 (0.3210)  loss_giou_3: 0.2320 (0.2639)  loss_ce_4: 2.2152 (2.5634)  loss_bbox_4: 0.2805 (0.3127)  loss_giou_4: 0.2174 (0.2609)  loss_ce_unscaled: 2.2517 (2.5681)  class_error_unscaled: 100.0000 (94.7540)  loss_bbox_unscaled: 0.0550 (0.0622)  loss_giou_unscaled: 0.1067 (0.1296)  cardinality_error_unscaled: 19.0000 (54.3962)  loss_ce_0_unscaled: 2.3283 (2.6483)  loss_bbox_0_unscaled: 0.0652 (0.0720)  loss_giou_0_unscaled: 0.0990 (0.1473)  cardinality_error_0_unscaled: 30.0000 (61.6038)  loss_ce_1_unscaled: 2.2416 (2.6303)  loss_bbox_1_unscaled: 0.0608 (0.0664)  loss_giou_1_unscaled: 0.1126 (0.1383)  cardinality_error_1_unscaled: 24.0000 (57.5314)  loss_ce_2_unscaled: 2.1706 (2.5469)  loss_bbox_2_unscaled: 0.0655 (0.0655)  loss_giou_2_unscaled: 0.1213 (0.1343)  cardinality_error_2_unscaled: 14.0000 (51.8270)  loss_ce_3_unscaled: 2.1886 (2.5473)  loss_bbox_3_unscaled: 0.0580 (0.0642)  loss_giou_3_unscaled: 0.1160 (0.1320)  cardinality_error_3_unscaled: 15.0000 (52.6038)  loss_ce_4_unscaled: 2.2152 (2.5634)  loss_bbox_4_unscaled: 0.0561 (0.0625)  loss_giou_4_unscaled: 0.1087 (0.1305)  cardinality_error_4_unscaled: 20.0000 (54.4591)
# hello from ('bbox',)
# Test: Total time: 0:00:20 (0.0638 s / it)
# Averaged stats: class_error: 100.00  loss: 17.1491 (17.0330)  loss_ce: 2.2547 (2.1246)  loss_bbox: 0.2772 (0.3675)  loss_giou: 0.2352 (0.2963)  loss_ce_0: 2.2705 (2.2274)  loss_bbox_0: 0.3580 (0.4386)  loss_giou_0: 0.2987 (0.3418)  loss_ce_1: 2.2899 (2.1893)  loss_bbox_1: 0.3105 (0.4043)  loss_giou_1: 0.2594 (0.3215)  loss_ce_2: 2.2158 (2.1041)  loss_bbox_2: 0.2581 (0.3846)  loss_giou_2: 0.2389 (0.3062)  loss_ce_3: 2.2166 (2.0781)  loss_bbox_3: 0.2724 (0.3763)  loss_giou_3: 0.2253 (0.3008)  loss_ce_4: 2.2368 (2.1079)  loss_bbox_4: 0.2356 (0.3662)  loss_giou_4: 0.2404 (0.2975)  loss_ce_unscaled: 2.2547 (2.1246)  class_error_unscaled: 100.0000 (95.9861)  loss_bbox_unscaled: 0.0554 (0.0735)  loss_giou_unscaled: 0.1176 (0.1481)  cardinality_error_unscaled: 12.0000 (11.3171)  loss_ce_0_unscaled: 2.2705 (2.2274)  loss_bbox_0_unscaled: 0.0716 (0.0877)  loss_giou_0_unscaled: 0.1494 (0.1709)  cardinality_error_0_unscaled: 16.0000 (16.3110)  loss_ce_1_unscaled: 2.2899 (2.1893)  loss_bbox_1_unscaled: 0.0621 (0.0809)  loss_giou_1_unscaled: 0.1297 (0.1608)  cardinality_error_1_unscaled: 14.0000 (13.7348)  loss_ce_2_unscaled: 2.2158 (2.1041)  loss_bbox_2_unscaled: 0.0516 (0.0769)  loss_giou_2_unscaled: 0.1194 (0.1531)  cardinality_error_2_unscaled: 5.0000 (8.5000)  loss_ce_3_unscaled: 2.2166 (2.0781)  loss_bbox_3_unscaled: 0.0545 (0.0753)  loss_giou_3_unscaled: 0.1127 (0.1504)  cardinality_error_3_unscaled: 7.0000 (9.2287)  loss_ce_4_unscaled: 2.2368 (2.1079)  loss_bbox_4_unscaled: 0.0471 (0.0732)  loss_giou_4_unscaled: 0.1202 (0.1488)  cardinality_error_4_unscaled: 12.0000 (10.3902)
# Accumulating evaluation results...
# DONE (t=0.35s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.00:0.75 | area=   all | maxDets=100 ] = 0.009
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.00:0.75 | area= small | maxDets=100 ] = 0.031
#  Average Precision  (AP) @[ IoU=0.00:0.75 | area=medium | maxDets=100 ] = 0.016
#  Average Precision  (AP) @[ IoU=0.00:0.75 | area= large | maxDets=100 ] = 0.011
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area=   all | maxDets=  1 ] = 0.119
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area=   all | maxDets= 10 ] = 0.209
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area=   all | maxDets=100 ] = 0.225
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area= small | maxDets=100 ] = 0.121
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area=medium | maxDets=100 ] = 0.221
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area= large | maxDets=100 ] = 0.230
# Epoch: [1] Total time: 0:00:47 (0.1487 s / it)
# Averaged stats: lr: 0.000010  class_error: 100.00  loss: 14.0582 (17.5001)  loss_ce: 1.9378 (2.0660)  loss_bbox: 0.1651 (0.4309)  loss_giou: 0.1542 (0.3389)  loss_ce_0: 2.1660 (2.2521)  loss_bbox_0: 0.1993 (0.4986)  loss_giou_0: 0.2035 (0.3914)  loss_ce_1: 2.0757 (2.1678)  loss_bbox_1: 0.1811 (0.4716)  loss_giou_1: 0.1779 (0.3669)  loss_ce_2: 1.9393 (2.0552)  loss_bbox_2: 0.1822 (0.4499)  loss_giou_2: 0.1494 (0.3531)  loss_ce_3: 1.9517 (2.0330)  loss_bbox_3: 0.1517 (0.4432)  loss_giou_3: 0.1743 (0.3510)  loss_ce_4: 1.9681 (2.0541)  loss_bbox_4: 0.1697 (0.4353)  loss_giou_4: 0.1466 (0.3412)  loss_ce_unscaled: 1.9378 (2.0660)  class_error_unscaled: 100.0000 (95.5930)  loss_bbox_unscaled: 0.0330 (0.0862)  loss_giou_unscaled: 0.0771 (0.1695)  cardinality_error_unscaled: 2.0000 (8.0818)  loss_ce_0_unscaled: 2.1660 (2.2521)  loss_bbox_0_unscaled: 0.0399 (0.0997)  loss_giou_0_unscaled: 0.1018 (0.1957)  cardinality_error_0_unscaled: 15.0000 (18.9340)  loss_ce_1_unscaled: 2.0757 (2.1678)  loss_bbox_1_unscaled: 0.0362 (0.0943)  loss_giou_1_unscaled: 0.0889 (0.1835)  cardinality_error_1_unscaled: 8.0000 (13.0660)  loss_ce_2_unscaled: 1.9393 (2.0552)  loss_bbox_2_unscaled: 0.0364 (0.0900)  loss_giou_2_unscaled: 0.0747 (0.1765)  cardinality_error_2_unscaled: 2.0000 (6.9748)  loss_ce_3_unscaled: 1.9517 (2.0330)  loss_bbox_3_unscaled: 0.0303 (0.0886)  loss_giou_3_unscaled: 0.0871 (0.1755)  cardinality_error_3_unscaled: 2.0000 (7.3239)  loss_ce_4_unscaled: 1.9681 (2.0541)  loss_bbox_4_unscaled: 0.0339 (0.0871)  loss_giou_4_unscaled: 0.0733 (0.1706)  cardinality_error_4_unscaled: 2.0000 (7.9874)
# hello from ('bbox',)
# Test: Total time: 0:00:21 (0.0643 s / it)
# Averaged stats: class_error: 100.00  loss: 15.7246 (16.1558)  loss_ce: 2.0710 (1.9723)  loss_bbox: 0.2743 (0.3624)  loss_giou: 0.2135 (0.2904)  loss_ce_0: 2.1746 (2.1173)  loss_bbox_0: 0.3051 (0.4279)  loss_giou_0: 0.2636 (0.3421)  loss_ce_1: 2.1246 (2.0621)  loss_bbox_1: 0.3018 (0.3977)  loss_giou_1: 0.2585 (0.3171)  loss_ce_2: 2.0580 (1.9572)  loss_bbox_2: 0.2798 (0.3792)  loss_giou_2: 0.2439 (0.3055)  loss_ce_3: 2.0435 (1.9385)  loss_bbox_3: 0.2722 (0.3699)  loss_giou_3: 0.2501 (0.2978)  loss_ce_4: 2.0577 (1.9577)  loss_bbox_4: 0.2813 (0.3659)  loss_giou_4: 0.2281 (0.2947)  loss_ce_unscaled: 2.0710 (1.9723)  class_error_unscaled: 100.0000 (96.7699)  loss_bbox_unscaled: 0.0549 (0.0725)  loss_giou_unscaled: 0.1067 (0.1452)  cardinality_error_unscaled: 2.0000 (3.5610)  loss_ce_0_unscaled: 2.1746 (2.1173)  loss_bbox_0_unscaled: 0.0610 (0.0856)  loss_giou_0_unscaled: 0.1318 (0.1710)  cardinality_error_0_unscaled: 5.0000 (7.1646)  loss_ce_1_unscaled: 2.1246 (2.0621)  loss_bbox_1_unscaled: 0.0604 (0.0795)  loss_giou_1_unscaled: 0.1293 (0.1586)  cardinality_error_1_unscaled: 5.0000 (5.4909)  loss_ce_2_unscaled: 2.0580 (1.9572)  loss_bbox_2_unscaled: 0.0560 (0.0758)  loss_giou_2_unscaled: 0.1220 (0.1528)  cardinality_error_2_unscaled: 1.0000 (3.0000)  loss_ce_3_unscaled: 2.0435 (1.9385)  loss_bbox_3_unscaled: 0.0544 (0.0740)  loss_giou_3_unscaled: 0.1251 (0.1489)  cardinality_error_3_unscaled: 2.0000 (3.1677)  loss_ce_4_unscaled: 2.0577 (1.9577)  loss_bbox_4_unscaled: 0.0563 (0.0732)  loss_giou_4_unscaled: 0.1141 (0.1473)  cardinality_error_4_unscaled: 2.0000 (3.2896)
# Accumulating evaluation results...
# DONE (t=0.35s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.00:0.75 | area=   all | maxDets=100 ] = 0.008
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.00:0.75 | area= small | maxDets=100 ] = 0.069
#  Average Precision  (AP) @[ IoU=0.00:0.75 | area=medium | maxDets=100 ] = 0.025
#  Average Precision  (AP) @[ IoU=0.00:0.75 | area= large | maxDets=100 ] = 0.012
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area=   all | maxDets=  1 ] = 0.105
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area=   all | maxDets= 10 ] = 0.187
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area=   all | maxDets=100 ] = 0.205
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area= small | maxDets=100 ] = 0.148
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area=medium | maxDets=100 ] = 0.185
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area= large | maxDets=100 ] = 0.213
# Epoch: [2] Total time: 0:00:47 (0.1499 s / it)
# Averaged stats: lr: 0.000010  class_error: 100.00  loss: 16.6323 (16.3053)  loss_ce: 1.9056 (1.9366)  loss_bbox: 0.3768 (0.3643)  loss_giou: 0.2419 (0.3133)  loss_ce_0: 2.1465 (2.1618)  loss_bbox_0: 0.5689 (0.4482)  loss_giou_0: 0.4019 (0.3714)  loss_ce_1: 2.0286 (2.0631)  loss_bbox_1: 0.4485 (0.4105)  loss_giou_1: 0.3155 (0.3434)  loss_ce_2: 1.9253 (1.9390)  loss_bbox_2: 0.4130 (0.3864)  loss_giou_2: 0.2577 (0.3299)  loss_ce_3: 1.8847 (1.9190)  loss_bbox_3: 0.4073 (0.3806)  loss_giou_3: 0.2747 (0.3227)  loss_ce_4: 1.9072 (1.9285)  loss_bbox_4: 0.3837 (0.3702)  loss_giou_4: 0.2426 (0.3164)  loss_ce_unscaled: 1.9056 (1.9366)  class_error_unscaled: 100.0000 (96.7954)  loss_bbox_unscaled: 0.0754 (0.0729)  loss_giou_unscaled: 0.1210 (0.1566)  cardinality_error_unscaled: 2.0000 (3.1289)  loss_ce_0_unscaled: 2.1465 (2.1618)  loss_bbox_0_unscaled: 0.1138 (0.0896)  loss_giou_0_unscaled: 0.2010 (0.1857)  cardinality_error_0_unscaled: 4.0000 (10.4371)  loss_ce_1_unscaled: 2.0286 (2.0631)  loss_bbox_1_unscaled: 0.0897 (0.0821)  loss_giou_1_unscaled: 0.1578 (0.1717)  cardinality_error_1_unscaled: 1.0000 (5.8585)  loss_ce_2_unscaled: 1.9253 (1.9390)  loss_bbox_2_unscaled: 0.0826 (0.0773)  loss_giou_2_unscaled: 0.1288 (0.1650)  cardinality_error_2_unscaled: 2.0000 (3.2390)  loss_ce_3_unscaled: 1.8847 (1.9190)  loss_bbox_3_unscaled: 0.0815 (0.0761)  loss_giou_3_unscaled: 0.1373 (0.1614)  cardinality_error_3_unscaled: 2.0000 (3.2767)  loss_ce_4_unscaled: 1.9072 (1.9285)  loss_bbox_4_unscaled: 0.0767 (0.0740)  loss_giou_4_unscaled: 0.1213 (0.1582)  cardinality_error_4_unscaled: 2.0000 (3.1226)
# hello from ('bbox',)
# Test: Total time: 0:00:21 (0.0644 s / it)
# Averaged stats: class_error: 100.00  loss: 16.5797 (16.0041)  loss_ce: 1.8892 (1.8231)  loss_bbox: 0.3183 (0.4196)  loss_giou: 0.2878 (0.3443)  loss_ce_0: 2.0734 (2.0356)  loss_bbox_0: 0.4690 (0.4751)  loss_giou_0: 0.3252 (0.3869)  loss_ce_1: 1.9696 (1.9290)  loss_bbox_1: 0.4355 (0.4523)  loss_giou_1: 0.3007 (0.3675)  loss_ce_2: 1.9072 (1.8122)  loss_bbox_2: 0.3397 (0.4364)  loss_giou_2: 0.2910 (0.3514)  loss_ce_3: 1.8684 (1.7994)  loss_bbox_3: 0.3546 (0.4409)  loss_giou_3: 0.2813 (0.3455)  loss_ce_4: 1.8758 (1.8191)  loss_bbox_4: 0.3314 (0.4260)  loss_giou_4: 0.2812 (0.3398)  loss_ce_unscaled: 1.8892 (1.8231)  class_error_unscaled: 100.0000 (97.3577)  loss_bbox_unscaled: 0.0637 (0.0839)  loss_giou_unscaled: 0.1439 (0.1722)  cardinality_error_unscaled: 2.0000 (2.2988)  loss_ce_0_unscaled: 2.0734 (2.0356)  loss_bbox_0_unscaled: 0.0938 (0.0950)  loss_giou_0_unscaled: 0.1626 (0.1934)  cardinality_error_0_unscaled: 2.0000 (2.7744)  loss_ce_1_unscaled: 1.9696 (1.9290)  loss_bbox_1_unscaled: 0.0871 (0.0905)  loss_giou_1_unscaled: 0.1504 (0.1837)  cardinality_error_1_unscaled: 2.0000 (2.4543)  loss_ce_2_unscaled: 1.9072 (1.8122)  loss_bbox_2_unscaled: 0.0679 (0.0873)  loss_giou_2_unscaled: 0.1455 (0.1757)  cardinality_error_2_unscaled: 2.0000 (2.5335)  loss_ce_3_unscaled: 1.8684 (1.7994)  loss_bbox_3_unscaled: 0.0709 (0.0882)  loss_giou_3_unscaled: 0.1406 (0.1728)  cardinality_error_3_unscaled: 2.0000 (2.5030)  loss_ce_4_unscaled: 1.8758 (1.8191)  loss_bbox_4_unscaled: 0.0663 (0.0852)  loss_giou_4_unscaled: 0.1406 (0.1699)  cardinality_error_4_unscaled: 2.0000 (2.3384)
# Accumulating evaluation results...
# DONE (t=0.35s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.00:0.75 | area=   all | maxDets=100 ] = 0.010
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.00:0.75 | area= small | maxDets=100 ] = 0.057
#  Average Precision  (AP) @[ IoU=0.00:0.75 | area=medium | maxDets=100 ] = 0.023
#  Average Precision  (AP) @[ IoU=0.00:0.75 | area= large | maxDets=100 ] = 0.011
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area=   all | maxDets=  1 ] = 0.114
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area=   all | maxDets= 10 ] = 0.184
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area=   all | maxDets=100 ] = 0.202
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area= small | maxDets=100 ] = 0.083
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area=medium | maxDets=100 ] = 0.166
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area= large | maxDets=100 ] = 0.215
# Epoch: [3] Total time: 0:00:46 (0.1461 s / it)
# Averaged stats: lr: 0.000010  class_error: 100.00  loss: 14.8729 (15.6944)  loss_ce: 1.8237 (1.8434)  loss_bbox: 0.2482 (0.3618)  loss_giou: 0.2282 (0.3077)  loss_ce_0: 2.0177 (2.0893)  loss_bbox_0: 0.2914 (0.4274)  loss_giou_0: 0.2674 (0.3463)  loss_ce_1: 1.9631 (1.9835)  loss_bbox_1: 0.2663 (0.3976)  loss_giou_1: 0.2388 (0.3255)  loss_ce_2: 1.8427 (1.8576)  loss_bbox_2: 0.2437 (0.3785)  loss_giou_2: 0.2235 (0.3175)  loss_ce_3: 1.8293 (1.8479)  loss_bbox_3: 0.2397 (0.3756)  loss_giou_3: 0.2389 (0.3149)  loss_ce_4: 1.8184 (1.8461)  loss_bbox_4: 0.2308 (0.3647)  loss_giou_4: 0.1968 (0.3092)  loss_ce_unscaled: 1.8237 (1.8434)  class_error_unscaled: 100.0000 (96.9340)  loss_bbox_unscaled: 0.0496 (0.0724)  loss_giou_unscaled: 0.1141 (0.1538)  cardinality_error_unscaled: 1.0000 (2.2264)  loss_ce_0_unscaled: 2.0177 (2.0893)  loss_bbox_0_unscaled: 0.0583 (0.0855)  loss_giou_0_unscaled: 0.1337 (0.1731)  cardinality_error_0_unscaled: 3.0000 (5.6604)  loss_ce_1_unscaled: 1.9631 (1.9835)  loss_bbox_1_unscaled: 0.0533 (0.0795)  loss_giou_1_unscaled: 0.1194 (0.1627)  cardinality_error_1_unscaled: 2.0000 (3.0314)  loss_ce_2_unscaled: 1.8427 (1.8576)  loss_bbox_2_unscaled: 0.0487 (0.0757)  loss_giou_2_unscaled: 0.1117 (0.1588)  cardinality_error_2_unscaled: 2.0000 (2.3365)  loss_ce_3_unscaled: 1.8293 (1.8479)  loss_bbox_3_unscaled: 0.0479 (0.0751)  loss_giou_3_unscaled: 0.1195 (0.1574)  cardinality_error_3_unscaled: 1.0000 (2.2893)  loss_ce_4_unscaled: 1.8184 (1.8461)  loss_bbox_4_unscaled: 0.0462 (0.0729)  loss_giou_4_unscaled: 0.0984 (0.1546)  cardinality_error_4_unscaled: 1.0000 (2.2484)
# hello from ('bbox',)
# Test: Total time: 0:00:21 (0.0651 s / it)
# Averaged stats: class_error: 100.00  loss: 16.9436 (15.6906)  loss_ce: 1.8687 (1.7875)  loss_bbox: 0.2884 (0.4082)  loss_giou: 0.2948 (0.3358)  loss_ce_0: 2.0296 (1.9944)  loss_bbox_0: 0.4059 (0.4541)  loss_giou_0: 0.3741 (0.3728)  loss_ce_1: 2.0012 (1.8988)  loss_bbox_1: 0.4048 (0.4359)  loss_giou_1: 0.3671 (0.3580)  loss_ce_2: 1.9229 (1.7976)  loss_bbox_2: 0.3073 (0.4186)  loss_giou_2: 0.2662 (0.3439)  loss_ce_3: 1.8716 (1.7923)  loss_bbox_3: 0.3082 (0.4114)  loss_giou_3: 0.2626 (0.3430)  loss_ce_4: 1.8930 (1.7918)  loss_bbox_4: 0.3209 (0.4096)  loss_giou_4: 0.2901 (0.3369)  loss_ce_unscaled: 1.8687 (1.7875)  class_error_unscaled: 100.0000 (97.4107)  loss_bbox_unscaled: 0.0577 (0.0816)  loss_giou_unscaled: 0.1474 (0.1679)  cardinality_error_unscaled: 2.0000 (2.2896)  loss_ce_0_unscaled: 2.0296 (1.9944)  loss_bbox_0_unscaled: 0.0812 (0.0908)  loss_giou_0_unscaled: 0.1870 (0.1864)  cardinality_error_0_unscaled: 2.0000 (2.4848)  loss_ce_1_unscaled: 2.0012 (1.8988)  loss_bbox_1_unscaled: 0.0810 (0.0872)  loss_giou_1_unscaled: 0.1835 (0.1790)  cardinality_error_1_unscaled: 2.0000 (2.2500)  loss_ce_2_unscaled: 1.9229 (1.7976)  loss_bbox_2_unscaled: 0.0615 (0.0837)  loss_giou_2_unscaled: 0.1331 (0.1720)  cardinality_error_2_unscaled: 2.0000 (2.4604)  loss_ce_3_unscaled: 1.8716 (1.7923)  loss_bbox_3_unscaled: 0.0616 (0.0823)  loss_giou_3_unscaled: 0.1313 (0.1715)  cardinality_error_3_unscaled: 2.0000 (2.5396)  loss_ce_4_unscaled: 1.8930 (1.7918)  loss_bbox_4_unscaled: 0.0642 (0.0819)  loss_giou_4_unscaled: 0.1451 (0.1685)  cardinality_error_4_unscaled: 2.0000 (2.3841)
# Accumulating evaluation results...
# DONE (t=0.33s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.00:0.75 | area=   all | maxDets=100 ] = 0.013
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.00:0.75 | area= small | maxDets=100 ] = 0.034
#  Average Precision  (AP) @[ IoU=0.00:0.75 | area=medium | maxDets=100 ] = 0.024
#  Average Precision  (AP) @[ IoU=0.00:0.75 | area= large | maxDets=100 ] = 0.016
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area=   all | maxDets=  1 ] = 0.109
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area=   all | maxDets= 10 ] = 0.173
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area=   all | maxDets=100 ] = 0.192
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area= small | maxDets=100 ] = 0.107
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area=medium | maxDets=100 ] = 0.166
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area= large | maxDets=100 ] = 0.201
# Epoch: [4] Total time: 0:00:46 (0.1473 s / it)
# Averaged stats: lr: 0.000010  class_error: 100.00  loss: 14.1353 (15.2470)  loss_ce: 1.6327 (1.8011)  loss_bbox: 0.3261 (0.3325)  loss_giou: 0.2792 (0.2965)  loss_ce_0: 1.9876 (2.0650)  loss_bbox_0: 0.3407 (0.4059)  loss_giou_0: 0.3042 (0.3410)  loss_ce_1: 1.8320 (1.9422)  loss_bbox_1: 0.2700 (0.3722)  loss_giou_1: 0.2968 (0.3203)  loss_ce_2: 1.7179 (1.8357)  loss_bbox_2: 0.3683 (0.3454)  loss_giou_2: 0.3237 (0.2987)  loss_ce_3: 1.7192 (1.8187)  loss_bbox_3: 0.3152 (0.3380)  loss_giou_3: 0.3059 (0.2948)  loss_ce_4: 1.6619 (1.8086)  loss_bbox_4: 0.3124 (0.3365)  loss_giou_4: 0.3040 (0.2936)  loss_ce_unscaled: 1.6327 (1.8011)  class_error_unscaled: 100.0000 (96.8100)  loss_bbox_unscaled: 0.0652 (0.0665)  loss_giou_unscaled: 0.1396 (0.1483)  cardinality_error_unscaled: 2.0000 (2.3365)  loss_ce_0_unscaled: 1.9876 (2.0650)  loss_bbox_0_unscaled: 0.0681 (0.0812)  loss_giou_0_unscaled: 0.1521 (0.1705)  cardinality_error_0_unscaled: 1.0000 (4.7421)  loss_ce_1_unscaled: 1.8320 (1.9422)  loss_bbox_1_unscaled: 0.0540 (0.0744)  loss_giou_1_unscaled: 0.1484 (0.1602)  cardinality_error_1_unscaled: 1.0000 (2.7704)  loss_ce_2_unscaled: 1.7179 (1.8357)  loss_bbox_2_unscaled: 0.0737 (0.0691)  loss_giou_2_unscaled: 0.1619 (0.1494)  cardinality_error_2_unscaled: 2.0000 (2.4182)  loss_ce_3_unscaled: 1.7192 (1.8187)  loss_bbox_3_unscaled: 0.0630 (0.0676)  loss_giou_3_unscaled: 0.1530 (0.1474)  cardinality_error_3_unscaled: 2.0000 (2.4811)  loss_ce_4_unscaled: 1.6619 (1.8086)  loss_bbox_4_unscaled: 0.0625 (0.0673)  loss_giou_4_unscaled: 0.1520 (0.1468)  cardinality_error_4_unscaled: 2.0000 (2.3208)
# hello from ('bbox',)
# Test: Total time: 0:00:21 (0.0644 s / it)
# Averaged stats: class_error: 100.00  loss: 17.3711 (16.4888)  loss_ce: 1.8074 (1.6966)  loss_bbox: 0.4836 (0.5360)  loss_giou: 0.4107 (0.3880)  loss_ce_0: 1.9730 (1.9570)  loss_bbox_0: 0.6388 (0.6329)  loss_giou_0: 0.4990 (0.4589)  loss_ce_1: 1.8883 (1.8132)  loss_bbox_1: 0.5639 (0.5941)  loss_giou_1: 0.4468 (0.4243)  loss_ce_2: 1.8385 (1.7155)  loss_bbox_2: 0.5301 (0.5667)  loss_giou_2: 0.4310 (0.4075)  loss_ce_3: 1.8150 (1.7160)  loss_bbox_3: 0.5852 (0.5475)  loss_giou_3: 0.4307 (0.3974)  loss_ce_4: 1.8071 (1.7005)  loss_bbox_4: 0.5005 (0.5426)  loss_giou_4: 0.4081 (0.3942)  loss_ce_unscaled: 1.8074 (1.6966)  class_error_unscaled: 100.0000 (97.2888)  loss_bbox_unscaled: 0.0967 (0.1072)  loss_giou_unscaled: 0.2054 (0.1940)  cardinality_error_unscaled: 2.0000 (2.4543)  loss_ce_0_unscaled: 1.9730 (1.9570)  loss_bbox_0_unscaled: 0.1278 (0.1266)  loss_giou_0_unscaled: 0.2495 (0.2295)  cardinality_error_0_unscaled: 2.0000 (2.5701)  loss_ce_1_unscaled: 1.8883 (1.8132)  loss_bbox_1_unscaled: 0.1128 (0.1188)  loss_giou_1_unscaled: 0.2234 (0.2122)  cardinality_error_1_unscaled: 2.0000 (2.3689)  loss_ce_2_unscaled: 1.8385 (1.7155)  loss_bbox_2_unscaled: 0.1060 (0.1133)  loss_giou_2_unscaled: 0.2155 (0.2038)  cardinality_error_2_unscaled: 2.0000 (2.5183)  loss_ce_3_unscaled: 1.8150 (1.7160)  loss_bbox_3_unscaled: 0.1170 (0.1095)  loss_giou_3_unscaled: 0.2154 (0.1987)  cardinality_error_3_unscaled: 2.0000 (2.5549)  loss_ce_4_unscaled: 1.8071 (1.7005)  loss_bbox_4_unscaled: 0.1001 (0.1085)  loss_giou_4_unscaled: 0.2041 (0.1971)  cardinality_error_4_unscaled: 2.0000 (2.4482)
# Accumulating evaluation results...
# DONE (t=0.36s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.00:0.75 | area=   all | maxDets=100 ] = 0.015
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.00:0.75 | area= small | maxDets=100 ] = 0.033
#  Average Precision  (AP) @[ IoU=0.00:0.75 | area=medium | maxDets=100 ] = 0.022
#  Average Precision  (AP) @[ IoU=0.00:0.75 | area= large | maxDets=100 ] = 0.017
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area=   all | maxDets=  1 ] = 0.132
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area=   all | maxDets= 10 ] = 0.214
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area=   all | maxDets=100 ] = 0.238
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area= small | maxDets=100 ] = 0.107
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area=medium | maxDets=100 ] = 0.172
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area= large | maxDets=100 ] = 0.252
# Epoch: [5] Total time: 0:00:46 (0.1451 s / it)
# Averaged stats: lr: 0.000010  class_error: 100.00  loss: 14.9947 (15.4876)  loss_ce: 1.7345 (1.7602)  loss_bbox: 0.2644 (0.3865)  loss_giou: 0.2303 (0.3220)  loss_ce_0: 2.0436 (2.0426)  loss_bbox_0: 0.4311 (0.4525)  loss_giou_0: 0.3472 (0.3695)  loss_ce_1: 1.9262 (1.9056)  loss_bbox_1: 0.2378 (0.4085)  loss_giou_1: 0.2420 (0.3425)  loss_ce_2: 1.7776 (1.8012)  loss_bbox_2: 0.2720 (0.3923)  loss_giou_2: 0.2097 (0.3277)  loss_ce_3: 1.7840 (1.7822)  loss_bbox_3: 0.2757 (0.3891)  loss_giou_3: 0.2489 (0.3232)  loss_ce_4: 1.7553 (1.7684)  loss_bbox_4: 0.2438 (0.3909)  loss_giou_4: 0.2261 (0.3226)  loss_ce_unscaled: 1.7345 (1.7602)  class_error_unscaled: 100.0000 (96.9946)  loss_bbox_unscaled: 0.0529 (0.0773)  loss_giou_unscaled: 0.1151 (0.1610)  cardinality_error_unscaled: 2.0000 (2.4528)  loss_ce_0_unscaled: 2.0436 (2.0426)  loss_bbox_0_unscaled: 0.0862 (0.0905)  loss_giou_0_unscaled: 0.1736 (0.1848)  cardinality_error_0_unscaled: 2.0000 (4.2987)  loss_ce_1_unscaled: 1.9262 (1.9056)  loss_bbox_1_unscaled: 0.0476 (0.0817)  loss_giou_1_unscaled: 0.1210 (0.1713)  cardinality_error_1_unscaled: 2.0000 (2.6730)  loss_ce_2_unscaled: 1.7776 (1.8012)  loss_bbox_2_unscaled: 0.0544 (0.0785)  loss_giou_2_unscaled: 0.1049 (0.1639)  cardinality_error_2_unscaled: 2.0000 (2.6761)  loss_ce_3_unscaled: 1.7840 (1.7822)  loss_bbox_3_unscaled: 0.0551 (0.0778)  loss_giou_3_unscaled: 0.1245 (0.1616)  cardinality_error_3_unscaled: 2.0000 (2.5566)  loss_ce_4_unscaled: 1.7553 (1.7684)  loss_bbox_4_unscaled: 0.0488 (0.0782)  loss_giou_4_unscaled: 0.1131 (0.1613)  cardinality_error_4_unscaled: 2.0000 (2.4686)
# hello from ('bbox',)
# Test: Total time: 0:00:21 (0.0647 s / it)
# Averaged stats: class_error: 100.00  loss: 15.6539 (15.1603)  loss_ce: 1.7797 (1.6992)  loss_bbox: 0.3274 (0.4002)  loss_giou: 0.2609 (0.3308)  loss_ce_0: 1.9670 (1.9564)  loss_bbox_0: 0.3740 (0.4524)  loss_giou_0: 0.3369 (0.3662)  loss_ce_1: 1.9059 (1.8112)  loss_bbox_1: 0.3453 (0.4287)  loss_giou_1: 0.2772 (0.3496)  loss_ce_2: 1.8158 (1.7201)  loss_bbox_2: 0.2829 (0.4130)  loss_giou_2: 0.2418 (0.3358)  loss_ce_3: 1.7907 (1.7091)  loss_bbox_3: 0.3379 (0.4118)  loss_giou_3: 0.2721 (0.3358)  loss_ce_4: 1.7945 (1.7062)  loss_bbox_4: 0.3492 (0.4056)  loss_giou_4: 0.2535 (0.3285)  loss_ce_unscaled: 1.7797 (1.6992)  class_error_unscaled: 100.0000 (97.2888)  loss_bbox_unscaled: 0.0655 (0.0800)  loss_giou_unscaled: 0.1305 (0.1654)  cardinality_error_unscaled: 2.0000 (2.3994)  loss_ce_0_unscaled: 1.9670 (1.9564)  loss_bbox_0_unscaled: 0.0748 (0.0905)  loss_giou_0_unscaled: 0.1685 (0.1831)  cardinality_error_0_unscaled: 2.0000 (2.1982)  loss_ce_1_unscaled: 1.9059 (1.8112)  loss_bbox_1_unscaled: 0.0691 (0.0857)  loss_giou_1_unscaled: 0.1386 (0.1748)  cardinality_error_1_unscaled: 2.0000 (2.3262)  loss_ce_2_unscaled: 1.8158 (1.7201)  loss_bbox_2_unscaled: 0.0566 (0.0826)  loss_giou_2_unscaled: 0.1209 (0.1679)  cardinality_error_2_unscaled: 2.0000 (2.5183)  loss_ce_3_unscaled: 1.7907 (1.7091)  loss_bbox_3_unscaled: 0.0676 (0.0824)  loss_giou_3_unscaled: 0.1360 (0.1679)  cardinality_error_3_unscaled: 2.0000 (2.4909)  loss_ce_4_unscaled: 1.7945 (1.7062)  loss_bbox_4_unscaled: 0.0698 (0.0811)  loss_giou_4_unscaled: 0.1267 (0.1643)  cardinality_error_4_unscaled: 2.0000 (2.3811)
# Accumulating evaluation results...
# DONE (t=0.34s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.00:0.75 | area=   all | maxDets=100 ] = 0.011
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.00:0.75 | area= small | maxDets=100 ] = 0.058
#  Average Precision  (AP) @[ IoU=0.00:0.75 | area=medium | maxDets=100 ] = 0.020
#  Average Precision  (AP) @[ IoU=0.00:0.75 | area= large | maxDets=100 ] = 0.012
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area=   all | maxDets=  1 ] = 0.122
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area=   all | maxDets= 10 ] = 0.196
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area=   all | maxDets=100 ] = 0.217
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area= small | maxDets=100 ] = 0.105
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area=medium | maxDets=100 ] = 0.146
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area= large | maxDets=100 ] = 0.238
# Epoch: [6] Total time: 0:00:46 (0.1458 s / it)
# Averaged stats: lr: 0.000010  class_error: 85.71  loss: 13.1801 (14.7075)  loss_ce: 1.6442 (1.7413)  loss_bbox: 0.1666 (0.3114)  loss_giou: 0.1369 (0.2832)  loss_ce_0: 1.8778 (2.0270)  loss_bbox_0: 0.1618 (0.3781)  loss_giou_0: 0.1548 (0.3268)  loss_ce_1: 1.7801 (1.8878)  loss_bbox_1: 0.1654 (0.3445)  loss_giou_1: 0.1516 (0.3003)  loss_ce_2: 1.6700 (1.7823)  loss_bbox_2: 0.1719 (0.3222)  loss_giou_2: 0.1399 (0.2851)  loss_ce_3: 1.6567 (1.7625)  loss_bbox_3: 0.1498 (0.3207)  loss_giou_3: 0.1186 (0.2850)  loss_ce_4: 1.6304 (1.7540)  loss_bbox_4: 0.1440 (0.3112)  loss_giou_4: 0.1500 (0.2841)  loss_ce_unscaled: 1.6442 (1.7413)  class_error_unscaled: 100.0000 (96.6824)  loss_bbox_unscaled: 0.0333 (0.0623)  loss_giou_unscaled: 0.0685 (0.1416)  cardinality_error_unscaled: 1.0000 (2.4434)  loss_ce_0_unscaled: 1.8778 (2.0270)  loss_bbox_0_unscaled: 0.0324 (0.0756)  loss_giou_0_unscaled: 0.0774 (0.1634)  cardinality_error_0_unscaled: 1.0000 (2.9371)  loss_ce_1_unscaled: 1.7801 (1.8878)  loss_bbox_1_unscaled: 0.0331 (0.0689)  loss_giou_1_unscaled: 0.0758 (0.1502)  cardinality_error_1_unscaled: 1.0000 (2.1478)  loss_ce_2_unscaled: 1.6700 (1.7823)  loss_bbox_2_unscaled: 0.0344 (0.0644)  loss_giou_2_unscaled: 0.0700 (0.1426)  cardinality_error_2_unscaled: 2.0000 (2.3931)  loss_ce_3_unscaled: 1.6567 (1.7625)  loss_bbox_3_unscaled: 0.0300 (0.0641)  loss_giou_3_unscaled: 0.0593 (0.1425)  cardinality_error_3_unscaled: 1.0000 (2.2925)  loss_ce_4_unscaled: 1.6304 (1.7540)  loss_bbox_4_unscaled: 0.0288 (0.0622)  loss_giou_4_unscaled: 0.0750 (0.1421)  cardinality_error_4_unscaled: 1.0000 (2.3899)
# hello from ('bbox',)
# Test: Total time: 0:00:21 (0.0640 s / it)
# Averaged stats: class_error: 100.00  loss: 15.2110 (14.8017)  loss_ce: 1.7764 (1.6533)  loss_bbox: 0.2808 (0.3802)  loss_giou: 0.2558 (0.3164)  loss_ce_0: 1.9375 (1.9446)  loss_bbox_0: 0.3941 (0.4540)  loss_giou_0: 0.2735 (0.3714)  loss_ce_1: 1.9027 (1.7807)  loss_bbox_1: 0.2425 (0.4203)  loss_giou_1: 0.2497 (0.3425)  loss_ce_2: 1.8162 (1.6784)  loss_bbox_2: 0.2978 (0.3906)  loss_giou_2: 0.2666 (0.3275)  loss_ce_3: 1.7933 (1.6704)  loss_bbox_3: 0.2966 (0.3865)  loss_giou_3: 0.2633 (0.3250)  loss_ce_4: 1.7830 (1.6590)  loss_bbox_4: 0.2942 (0.3830)  loss_giou_4: 0.2645 (0.3180)  loss_ce_unscaled: 1.7764 (1.6533)  class_error_unscaled: 100.0000 (97.2888)  loss_bbox_unscaled: 0.0562 (0.0760)  loss_giou_unscaled: 0.1279 (0.1582)  cardinality_error_unscaled: 2.0000 (2.4665)  loss_ce_0_unscaled: 1.9375 (1.9446)  loss_bbox_0_unscaled: 0.0788 (0.0908)  loss_giou_0_unscaled: 0.1367 (0.1857)  cardinality_error_0_unscaled: 2.0000 (2.1799)  loss_ce_1_unscaled: 1.9027 (1.7807)  loss_bbox_1_unscaled: 0.0485 (0.0841)  loss_giou_1_unscaled: 0.1249 (0.1712)  cardinality_error_1_unscaled: 2.0000 (2.4360)  loss_ce_2_unscaled: 1.8162 (1.6784)  loss_bbox_2_unscaled: 0.0596 (0.0781)  loss_giou_2_unscaled: 0.1333 (0.1638)  cardinality_error_2_unscaled: 2.0000 (2.4909)  loss_ce_3_unscaled: 1.7933 (1.6704)  loss_bbox_3_unscaled: 0.0593 (0.0773)  loss_giou_3_unscaled: 0.1317 (0.1625)  cardinality_error_3_unscaled: 2.0000 (2.5061)  loss_ce_4_unscaled: 1.7830 (1.6590)  loss_bbox_4_unscaled: 0.0588 (0.0766)  loss_giou_4_unscaled: 0.1323 (0.1590)  cardinality_error_4_unscaled: 2.0000 (2.4909)
# Accumulating evaluation results...
# DONE (t=0.35s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.00:0.75 | area=   all | maxDets=100 ] = 0.018
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.00:0.75 | area= small | maxDets=100 ] = 0.060
#  Average Precision  (AP) @[ IoU=0.00:0.75 | area=medium | maxDets=100 ] = 0.037
#  Average Precision  (AP) @[ IoU=0.00:0.75 | area= large | maxDets=100 ] = 0.019
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area=   all | maxDets=  1 ] = 0.117
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area=   all | maxDets= 10 ] = 0.189
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area=   all | maxDets=100 ] = 0.222
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area= small | maxDets=100 ] = 0.112
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area=medium | maxDets=100 ] = 0.165
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area= large | maxDets=100 ] = 0.230
# Epoch: [7] Total time: 0:00:46 (0.1457 s / it)
# Averaged stats: lr: 0.000010  class_error: 100.00  loss: 14.8100 (14.6029)  loss_ce: 1.7101 (1.7106)  loss_bbox: 0.2303 (0.3101)  loss_giou: 0.2207 (0.2868)  loss_ce_0: 2.0550 (2.0181)  loss_bbox_0: 0.4287 (0.3855)  loss_giou_0: 0.2708 (0.3333)  loss_ce_1: 1.8480 (1.8682)  loss_bbox_1: 0.4137 (0.3492)  loss_giou_1: 0.2737 (0.3054)  loss_ce_2: 1.7795 (1.7604)  loss_bbox_2: 0.2599 (0.3195)  loss_giou_2: 0.2114 (0.2901)  loss_ce_3: 1.7382 (1.7321)  loss_bbox_3: 0.2682 (0.3144)  loss_giou_3: 0.2475 (0.2905)  loss_ce_4: 1.6998 (1.7187)  loss_bbox_4: 0.2502 (0.3171)  loss_giou_4: 0.2189 (0.2929)  loss_ce_unscaled: 1.7101 (1.7106)  class_error_unscaled: 100.0000 (96.9186)  loss_bbox_unscaled: 0.0461 (0.0620)  loss_giou_unscaled: 0.1103 (0.1434)  cardinality_error_unscaled: 2.0000 (2.3491)  loss_ce_0_unscaled: 2.0550 (2.0181)  loss_bbox_0_unscaled: 0.0857 (0.0771)  loss_giou_0_unscaled: 0.1354 (0.1667)  cardinality_error_0_unscaled: 1.0000 (3.2358)  loss_ce_1_unscaled: 1.8480 (1.8682)  loss_bbox_1_unscaled: 0.0827 (0.0698)  loss_giou_1_unscaled: 0.1369 (0.1527)  cardinality_error_1_unscaled: 2.0000 (2.2390)  loss_ce_2_unscaled: 1.7795 (1.7604)  loss_bbox_2_unscaled: 0.0520 (0.0639)  loss_giou_2_unscaled: 0.1057 (0.1450)  cardinality_error_2_unscaled: 2.0000 (2.2673)  loss_ce_3_unscaled: 1.7382 (1.7321)  loss_bbox_3_unscaled: 0.0536 (0.0629)  loss_giou_3_unscaled: 0.1237 (0.1452)  cardinality_error_3_unscaled: 2.0000 (2.2736)  loss_ce_4_unscaled: 1.6998 (1.7187)  loss_bbox_4_unscaled: 0.0500 (0.0634)  loss_giou_4_unscaled: 0.1094 (0.1464)  cardinality_error_4_unscaled: 2.0000 (2.3019)
# hello from ('bbox',)
# Test: Total time: 0:00:21 (0.0642 s / it)
# Averaged stats: class_error: 100.00  loss: 14.8384 (14.8878)  loss_ce: 1.7522 (1.6370)  loss_bbox: 0.2701 (0.3879)  loss_giou: 0.2151 (0.3246)  loss_ce_0: 1.9293 (1.9433)  loss_bbox_0: 0.3782 (0.4661)  loss_giou_0: 0.2448 (0.3757)  loss_ce_1: 1.8761 (1.8024)  loss_bbox_1: 0.2704 (0.4306)  loss_giou_1: 0.2417 (0.3558)  loss_ce_2: 1.8053 (1.6870)  loss_bbox_2: 0.2812 (0.4003)  loss_giou_2: 0.2277 (0.3367)  loss_ce_3: 1.7815 (1.6613)  loss_bbox_3: 0.2649 (0.3956)  loss_giou_3: 0.2255 (0.3309)  loss_ce_4: 1.7479 (1.6473)  loss_bbox_4: 0.2493 (0.3835)  loss_giou_4: 0.2176 (0.3220)  loss_ce_unscaled: 1.7522 (1.6370)  class_error_unscaled: 100.0000 (97.1596)  loss_bbox_unscaled: 0.0540 (0.0776)  loss_giou_unscaled: 0.1075 (0.1623)  cardinality_error_unscaled: 2.0000 (2.4390)  loss_ce_0_unscaled: 1.9293 (1.9433)  loss_bbox_0_unscaled: 0.0756 (0.0932)  loss_giou_0_unscaled: 0.1224 (0.1879)  cardinality_error_0_unscaled: 2.0000 (2.1067)  loss_ce_1_unscaled: 1.8761 (1.8024)  loss_bbox_1_unscaled: 0.0541 (0.0861)  loss_giou_1_unscaled: 0.1208 (0.1779)  cardinality_error_1_unscaled: 2.0000 (2.3963)  loss_ce_2_unscaled: 1.8053 (1.6870)  loss_bbox_2_unscaled: 0.0562 (0.0801)  loss_giou_2_unscaled: 0.1139 (0.1683)  cardinality_error_2_unscaled: 2.0000 (2.4848)  loss_ce_3_unscaled: 1.7815 (1.6613)  loss_bbox_3_unscaled: 0.0530 (0.0791)  loss_giou_3_unscaled: 0.1128 (0.1655)  cardinality_error_3_unscaled: 2.0000 (2.4939)  loss_ce_4_unscaled: 1.7479 (1.6473)  loss_bbox_4_unscaled: 0.0499 (0.0767)  loss_giou_4_unscaled: 0.1088 (0.1610)  cardinality_error_4_unscaled: 2.0000 (2.4573)
# Accumulating evaluation results...
# DONE (t=0.33s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.00:0.75 | area=   all | maxDets=100 ] = 0.027
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.00:0.75 | area= small | maxDets=100 ] = 0.042
#  Average Precision  (AP) @[ IoU=0.00:0.75 | area=medium | maxDets=100 ] = 0.039
#  Average Precision  (AP) @[ IoU=0.00:0.75 | area= large | maxDets=100 ] = 0.030
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area=   all | maxDets=  1 ] = 0.116
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area=   all | maxDets= 10 ] = 0.172
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area=   all | maxDets=100 ] = 0.201
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area= small | maxDets=100 ] = 0.088
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area=medium | maxDets=100 ] = 0.151
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area= large | maxDets=100 ] = 0.210
# Epoch: [8] Total time: 0:00:46 (0.1453 s / it)
# Averaged stats: lr: 0.000010  class_error: 100.00  loss: 13.3400 (14.4026)  loss_ce: 1.5300 (1.6762)  loss_bbox: 0.1925 (0.3100)  loss_giou: 0.1786 (0.2781)  loss_ce_0: 1.8979 (1.9948)  loss_bbox_0: 0.2927 (0.3790)  loss_giou_0: 0.2684 (0.3307)  loss_ce_1: 1.7306 (1.8454)  loss_bbox_1: 0.2281 (0.3534)  loss_giou_1: 0.2340 (0.2962)  loss_ce_2: 1.6120 (1.7330)  loss_bbox_2: 0.2222 (0.3336)  loss_giou_2: 0.1916 (0.2871)  loss_ce_3: 1.5702 (1.7088)  loss_bbox_3: 0.2055 (0.3163)  loss_giou_3: 0.1863 (0.2787)  loss_ce_4: 1.5526 (1.6869)  loss_bbox_4: 0.1923 (0.3162)  loss_giou_4: 0.1715 (0.2784)  loss_ce_unscaled: 1.5300 (1.6762)  class_error_unscaled: 100.0000 (96.6277)  loss_bbox_unscaled: 0.0385 (0.0620)  loss_giou_unscaled: 0.0893 (0.1390)  cardinality_error_unscaled: 2.0000 (2.3742)  loss_ce_0_unscaled: 1.8979 (1.9948)  loss_bbox_0_unscaled: 0.0585 (0.0758)  loss_giou_0_unscaled: 0.1342 (0.1654)  cardinality_error_0_unscaled: 2.0000 (2.3805)  loss_ce_1_unscaled: 1.7306 (1.8454)  loss_bbox_1_unscaled: 0.0456 (0.0707)  loss_giou_1_unscaled: 0.1170 (0.1481)  cardinality_error_1_unscaled: 2.0000 (1.9591)  loss_ce_2_unscaled: 1.6120 (1.7330)  loss_bbox_2_unscaled: 0.0444 (0.0667)  loss_giou_2_unscaled: 0.0958 (0.1435)  cardinality_error_2_unscaled: 2.0000 (2.3239)  loss_ce_3_unscaled: 1.5702 (1.7088)  loss_bbox_3_unscaled: 0.0411 (0.0633)  loss_giou_3_unscaled: 0.0932 (0.1393)  cardinality_error_3_unscaled: 2.0000 (2.3050)  loss_ce_4_unscaled: 1.5526 (1.6869)  loss_bbox_4_unscaled: 0.0385 (0.0632)  loss_giou_4_unscaled: 0.0857 (0.1392)  cardinality_error_4_unscaled: 2.0000 (2.3428)
# hello from ('bbox',)
# Test: Total time: 0:00:21 (0.0646 s / it)
# Averaged stats: class_error: 100.00  loss: 15.2811 (14.8072)  loss_ce: 1.7020 (1.5951)  loss_bbox: 0.3978 (0.4048)  loss_giou: 0.2719 (0.3386)  loss_ce_0: 1.9149 (1.9257)  loss_bbox_0: 0.4347 (0.4662)  loss_giou_0: 0.3023 (0.3894)  loss_ce_1: 1.8247 (1.7537)  loss_bbox_1: 0.3886 (0.4424)  loss_giou_1: 0.3077 (0.3558)  loss_ce_2: 1.7328 (1.6421)  loss_bbox_2: 0.3996 (0.4137)  loss_giou_2: 0.2922 (0.3471)  loss_ce_3: 1.7289 (1.6254)  loss_bbox_3: 0.4279 (0.4098)  loss_giou_3: 0.2836 (0.3423)  loss_ce_4: 1.7056 (1.6109)  loss_bbox_4: 0.3981 (0.4069)  loss_giou_4: 0.2997 (0.3375)  loss_ce_unscaled: 1.7020 (1.5951)  class_error_unscaled: 100.0000 (97.1596)  loss_bbox_unscaled: 0.0796 (0.0810)  loss_giou_unscaled: 0.1359 (0.1693)  cardinality_error_unscaled: 2.0000 (2.4421)  loss_ce_0_unscaled: 1.9149 (1.9257)  loss_bbox_0_unscaled: 0.0869 (0.0932)  loss_giou_0_unscaled: 0.1511 (0.1947)  cardinality_error_0_unscaled: 2.0000 (1.9939)  loss_ce_1_unscaled: 1.8247 (1.7537)  loss_bbox_1_unscaled: 0.0777 (0.0885)  loss_giou_1_unscaled: 0.1538 (0.1779)  cardinality_error_1_unscaled: 2.0000 (2.3902)  loss_ce_2_unscaled: 1.7328 (1.6421)  loss_bbox_2_unscaled: 0.0799 (0.0827)  loss_giou_2_unscaled: 0.1461 (0.1735)  cardinality_error_2_unscaled: 2.0000 (2.4421)  loss_ce_3_unscaled: 1.7289 (1.6254)  loss_bbox_3_unscaled: 0.0856 (0.0820)  loss_giou_3_unscaled: 0.1418 (0.1712)  cardinality_error_3_unscaled: 2.0000 (2.4604)  loss_ce_4_unscaled: 1.7056 (1.6109)  loss_bbox_4_unscaled: 0.0796 (0.0814)  loss_giou_4_unscaled: 0.1498 (0.1687)  cardinality_error_4_unscaled: 2.0000 (2.4451)
# Accumulating evaluation results...
# DONE (t=0.33s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.00:0.75 | area=   all | maxDets=100 ] = 0.029
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.00:0.75 | area= small | maxDets=100 ] = 0.048
#  Average Precision  (AP) @[ IoU=0.00:0.75 | area=medium | maxDets=100 ] = 0.034
#  Average Precision  (AP) @[ IoU=0.00:0.75 | area= large | maxDets=100 ] = 0.029
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area=   all | maxDets=  1 ] = 0.128
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area=   all | maxDets= 10 ] = 0.192
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area=   all | maxDets=100 ] = 0.218
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area= small | maxDets=100 ] = 0.069
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area=medium | maxDets=100 ] = 0.143
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area= large | maxDets=100 ] = 0.231
# Epoch: [9] Total time: 0:00:46 (0.1459 s / it)
# Averaged stats: lr: 0.000010  class_error: 100.00  loss: 14.4959 (14.4643)  loss_ce: 1.6122 (1.6376)  loss_bbox: 0.2467 (0.3412)  loss_giou: 0.2093 (0.2940)  loss_ce_0: 1.9594 (1.9706)  loss_bbox_0: 0.3136 (0.4112)  loss_giou_0: 0.2351 (0.3469)  loss_ce_1: 1.7914 (1.8159)  loss_bbox_1: 0.2992 (0.3657)  loss_giou_1: 0.1980 (0.3181)  loss_ce_2: 1.6616 (1.7079)  loss_bbox_2: 0.1899 (0.3485)  loss_giou_2: 0.2144 (0.3013)  loss_ce_3: 1.6453 (1.6771)  loss_bbox_3: 0.2304 (0.3441)  loss_giou_3: 0.2153 (0.2936)  loss_ce_4: 1.6113 (1.6504)  loss_bbox_4: 0.2164 (0.3469)  loss_giou_4: 0.2157 (0.2934)  loss_ce_unscaled: 1.6122 (1.6376)  class_error_unscaled: 100.0000 (96.8344)  loss_bbox_unscaled: 0.0493 (0.0682)  loss_giou_unscaled: 0.1047 (0.1470)  cardinality_error_unscaled: 2.0000 (2.4528)  loss_ce_0_unscaled: 1.9594 (1.9706)  loss_bbox_0_unscaled: 0.0627 (0.0822)  loss_giou_0_unscaled: 0.1175 (0.1734)  cardinality_error_0_unscaled: 1.0000 (2.0503)  loss_ce_1_unscaled: 1.7914 (1.8159)  loss_bbox_1_unscaled: 0.0598 (0.0731)  loss_giou_1_unscaled: 0.0990 (0.1591)  cardinality_error_1_unscaled: 2.0000 (2.1101)  loss_ce_2_unscaled: 1.6616 (1.7079)  loss_bbox_2_unscaled: 0.0380 (0.0697)  loss_giou_2_unscaled: 0.1072 (0.1506)  cardinality_error_2_unscaled: 2.0000 (2.3616)  loss_ce_3_unscaled: 1.6453 (1.6771)  loss_bbox_3_unscaled: 0.0461 (0.0688)  loss_giou_3_unscaled: 0.1076 (0.1468)  cardinality_error_3_unscaled: 2.0000 (2.3994)  loss_ce_4_unscaled: 1.6113 (1.6504)  loss_bbox_4_unscaled: 0.0433 (0.0694)  loss_giou_4_unscaled: 0.1078 (0.1467)  cardinality_error_4_unscaled: 2.0000 (2.4465)
# hello from ('bbox',)
# Test: Total time: 0:00:21 (0.0658 s / it)
# Averaged stats: class_error: 100.00  loss: 14.7667 (14.6178)  loss_ce: 1.7226 (1.6060)  loss_bbox: 0.2871 (0.3916)  loss_giou: 0.2335 (0.3177)  loss_ce_0: 1.9500 (1.9303)  loss_bbox_0: 0.3266 (0.4339)  loss_giou_0: 0.2400 (0.3525)  loss_ce_1: 1.8720 (1.7718)  loss_bbox_1: 0.3418 (0.4197)  loss_giou_1: 0.2652 (0.3366)  loss_ce_2: 1.7928 (1.6598)  loss_bbox_2: 0.2914 (0.3975)  loss_giou_2: 0.2303 (0.3227)  loss_ce_3: 1.7370 (1.6345)  loss_bbox_3: 0.2845 (0.4023)  loss_giou_3: 0.2276 (0.3198)  loss_ce_4: 1.7027 (1.6137)  loss_bbox_4: 0.2865 (0.3912)  loss_giou_4: 0.2395 (0.3162)  loss_ce_unscaled: 1.7226 (1.6060)  class_error_unscaled: 100.0000 (97.2510)  loss_bbox_unscaled: 0.0574 (0.0783)  loss_giou_unscaled: 0.1168 (0.1589)  cardinality_error_unscaled: 2.0000 (2.4573)  loss_ce_0_unscaled: 1.9500 (1.9303)  loss_bbox_0_unscaled: 0.0653 (0.0868)  loss_giou_0_unscaled: 0.1200 (0.1762)  cardinality_error_0_unscaled: 2.0000 (2.1067)  loss_ce_1_unscaled: 1.8720 (1.7718)  loss_bbox_1_unscaled: 0.0684 (0.0839)  loss_giou_1_unscaled: 0.1326 (0.1683)  cardinality_error_1_unscaled: 2.0000 (2.3841)  loss_ce_2_unscaled: 1.7928 (1.6598)  loss_bbox_2_unscaled: 0.0583 (0.0795)  loss_giou_2_unscaled: 0.1151 (0.1613)  cardinality_error_2_unscaled: 2.0000 (2.4573)  loss_ce_3_unscaled: 1.7370 (1.6345)  loss_bbox_3_unscaled: 0.0569 (0.0805)  loss_giou_3_unscaled: 0.1138 (0.1599)  cardinality_error_3_unscaled: 2.0000 (2.4482)  loss_ce_4_unscaled: 1.7027 (1.6137)  loss_bbox_4_unscaled: 0.0573 (0.0782)  loss_giou_4_unscaled: 0.1197 (0.1581)  cardinality_error_4_unscaled: 2.0000 (2.4573)
# Accumulating evaluation results...
# DONE (t=0.33s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.00:0.75 | area=   all | maxDets=100 ] = 0.028
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.00:0.75 | area= small | maxDets=100 ] = 0.051
#  Average Precision  (AP) @[ IoU=0.00:0.75 | area=medium | maxDets=100 ] = 0.042
#  Average Precision  (AP) @[ IoU=0.00:0.75 | area= large | maxDets=100 ] = 0.029
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area=   all | maxDets=  1 ] = 0.131
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area=   all | maxDets= 10 ] = 0.196
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area=   all | maxDets=100 ] = 0.225
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area= small | maxDets=100 ] = 0.079
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area=medium | maxDets=100 ] = 0.171
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area= large | maxDets=100 ] = 0.235
# Epoch: [10] Total time: 0:00:46 (0.1458 s / it)
# Averaged stats: lr: 0.000010  class_error: 100.00  loss: 14.2939 (14.0047)  loss_ce: 1.7671 (1.6581)  loss_bbox: 0.2936 (0.2842)  loss_giou: 0.2202 (0.2658)  loss_ce_0: 2.0064 (1.9808)  loss_bbox_0: 0.4041 (0.3443)  loss_giou_0: 0.2678 (0.3051)  loss_ce_1: 1.9109 (1.8252)  loss_bbox_1: 0.3374 (0.3106)  loss_giou_1: 0.2335 (0.2820)  loss_ce_2: 1.8103 (1.7168)  loss_bbox_2: 0.3135 (0.2972)  loss_giou_2: 0.2580 (0.2698)  loss_ce_3: 1.7758 (1.6908)  loss_bbox_3: 0.2891 (0.2859)  loss_giou_3: 0.2285 (0.2680)  loss_ce_4: 1.7762 (1.6683)  loss_bbox_4: 0.2947 (0.2859)  loss_giou_4: 0.2045 (0.2658)  loss_ce_unscaled: 1.7671 (1.6581)  class_error_unscaled: 100.0000 (96.9340)  loss_bbox_unscaled: 0.0587 (0.0568)  loss_giou_unscaled: 0.1101 (0.1329)  cardinality_error_unscaled: 3.0000 (2.3333)  loss_ce_0_unscaled: 2.0064 (1.9808)  loss_bbox_0_unscaled: 0.0808 (0.0689)  loss_giou_0_unscaled: 0.1339 (0.1525)  cardinality_error_0_unscaled: 1.0000 (2.5943)  loss_ce_1_unscaled: 1.9109 (1.8252)  loss_bbox_1_unscaled: 0.0675 (0.0621)  loss_giou_1_unscaled: 0.1168 (0.1410)  cardinality_error_1_unscaled: 2.0000 (2.2610)  loss_ce_2_unscaled: 1.8103 (1.7168)  loss_bbox_2_unscaled: 0.0627 (0.0594)  loss_giou_2_unscaled: 0.1290 (0.1349)  cardinality_error_2_unscaled: 3.0000 (2.3491)  loss_ce_3_unscaled: 1.7758 (1.6908)  loss_bbox_3_unscaled: 0.0578 (0.0572)  loss_giou_3_unscaled: 0.1142 (0.1340)  cardinality_error_3_unscaled: 3.0000 (2.3208)  loss_ce_4_unscaled: 1.7762 (1.6683)  loss_bbox_4_unscaled: 0.0589 (0.0572)  loss_giou_4_unscaled: 0.1022 (0.1329)  cardinality_error_4_unscaled: 3.0000 (2.3302)
# hello from ('bbox',)
# Test: Total time: 0:00:21 (0.0648 s / it)
# Averaged stats: class_error: 100.00  loss: 14.4365 (14.2436)  loss_ce: 1.6976 (1.6053)  loss_bbox: 0.2529 (0.3564)  loss_giou: 0.1987 (0.3050)  loss_ce_0: 1.9372 (1.9254)  loss_bbox_0: 0.2821 (0.3851)  loss_giou_0: 0.2144 (0.3417)  loss_ce_1: 1.8271 (1.7395)  loss_bbox_1: 0.2713 (0.3732)  loss_giou_1: 0.2041 (0.3220)  loss_ce_2: 1.7484 (1.6388)  loss_bbox_2: 0.2616 (0.3645)  loss_giou_2: 0.1915 (0.3109)  loss_ce_3: 1.7274 (1.6374)  loss_bbox_3: 0.2819 (0.3611)  loss_giou_3: 0.2133 (0.3060)  loss_ce_4: 1.6860 (1.6158)  loss_bbox_4: 0.2623 (0.3525)  loss_giou_4: 0.2154 (0.3030)  loss_ce_unscaled: 1.6976 (1.6053)  class_error_unscaled: 100.0000 (97.2075)  loss_bbox_unscaled: 0.0506 (0.0713)  loss_giou_unscaled: 0.0993 (0.1525)  cardinality_error_unscaled: 2.0000 (2.4299)  loss_ce_0_unscaled: 1.9372 (1.9254)  loss_bbox_0_unscaled: 0.0564 (0.0770)  loss_giou_0_unscaled: 0.1072 (0.1709)  cardinality_error_0_unscaled: 2.0000 (2.1555)  loss_ce_1_unscaled: 1.8271 (1.7395)  loss_bbox_1_unscaled: 0.0543 (0.0746)  loss_giou_1_unscaled: 0.1020 (0.1610)  cardinality_error_1_unscaled: 2.0000 (2.3384)  loss_ce_2_unscaled: 1.7484 (1.6388)  loss_bbox_2_unscaled: 0.0523 (0.0729)  loss_giou_2_unscaled: 0.0957 (0.1554)  cardinality_error_2_unscaled: 2.0000 (2.4451)  loss_ce_3_unscaled: 1.7274 (1.6374)  loss_bbox_3_unscaled: 0.0564 (0.0722)  loss_giou_3_unscaled: 0.1066 (0.1530)  cardinality_error_3_unscaled: 2.0000 (2.4695)  loss_ce_4_unscaled: 1.6860 (1.6158)  loss_bbox_4_unscaled: 0.0525 (0.0705)  loss_giou_4_unscaled: 0.1077 (0.1515)  cardinality_error_4_unscaled: 2.0000 (2.4451)
# Accumulating evaluation results...
# DONE (t=0.35s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.00:0.75 | area=   all | maxDets=100 ] = 0.026
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.00:0.75 | area= small | maxDets=100 ] = 0.053
#  Average Precision  (AP) @[ IoU=0.00:0.75 | area=medium | maxDets=100 ] = 0.026
#  Average Precision  (AP) @[ IoU=0.00:0.75 | area= large | maxDets=100 ] = 0.027
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area=   all | maxDets=  1 ] = 0.148
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area=   all | maxDets= 10 ] = 0.222
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area=   all | maxDets=100 ] = 0.248
# ...
# Accumulating evaluation results...
# DONE (t=0.34s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.00:0.75 | area=   all | maxDets=100 ] = 0.052
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.00:0.75 | area= small | maxDets=100 ] = 0.068
#  Average Precision  (AP) @[ IoU=0.00:0.75 | area=medium | maxDets=100 ] = 0.064
#  Average Precision  (AP) @[ IoU=0.00:0.75 | area= large | maxDets=100 ] = 0.048
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area=   all | maxDets=  1 ] = 0.164
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area=   all | maxDets= 10 ] = 0.265
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area=   all | maxDets=100 ] = 0.286
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area= small | maxDets=100 ] = 0.129
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area=medium | maxDets=100 ] = 0.250
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area= large | maxDets=100 ] = 0.290
# Epoch: [39] Total time: 0:00:45 (0.1441 s / it)
# Averaged stats: lr: 0.000010  class_error: 100.00  loss: 11.0573 (11.8733)  loss_ce: 1.3070 (1.3996)  loss_bbox: 0.1099 (0.2277)  loss_giou: 0.1107 (0.2161)  loss_ce_0: 1.6698 (1.7452)  loss_bbox_0: 0.2307 (0.2934)  loss_giou_0: 0.1869 (0.2644)  loss_ce_1: 1.4860 (1.5605)  loss_bbox_1: 0.1451 (0.2565)  loss_giou_1: 0.1662 (0.2364)  loss_ce_2: 1.3665 (1.4651)  loss_bbox_2: 0.1375 (0.2422)  loss_giou_2: 0.1482 (0.2211)  loss_ce_3: 1.3342 (1.4294)  loss_bbox_3: 0.1426 (0.2332)  loss_giou_3: 0.1226 (0.2207)  loss_ce_4: 1.3038 (1.4124)  loss_bbox_4: 0.1297 (0.2331)  loss_giou_4: 0.1241 (0.2163)  loss_ce_unscaled: 1.3070 (1.3996)  class_error_unscaled: 100.0000 (94.7881)  loss_bbox_unscaled: 0.0220 (0.0455)  loss_giou_unscaled: 0.0554 (0.1081)  cardinality_error_unscaled: 2.0000 (2.4403)  loss_ce_0_unscaled: 1.6698 (1.7452)  loss_bbox_0_unscaled: 0.0461 (0.0587)  loss_giou_0_unscaled: 0.0935 (0.1322)  cardinality_error_0_unscaled: 1.0000 (2.5031)  loss_ce_1_unscaled: 1.4860 (1.5605)  loss_bbox_1_unscaled: 0.0290 (0.0513)  loss_giou_1_unscaled: 0.0831 (0.1182)  cardinality_error_1_unscaled: 2.0000 (2.2893)  loss_ce_2_unscaled: 1.3665 (1.4651)  loss_bbox_2_unscaled: 0.0275 (0.0484)  loss_giou_2_unscaled: 0.0741 (0.1106)  cardinality_error_2_unscaled: 2.0000 (2.4560)  loss_ce_3_unscaled: 1.3342 (1.4294)  loss_bbox_3_unscaled: 0.0285 (0.0466)  loss_giou_3_unscaled: 0.0613 (0.1103)  cardinality_error_3_unscaled: 2.0000 (2.3994)  loss_ce_4_unscaled: 1.3038 (1.4124)  loss_bbox_4_unscaled: 0.0259 (0.0466)  loss_giou_4_unscaled: 0.0620 (0.1081)  cardinality_error_4_unscaled: 2.0000 (2.4340)
# hello from ('bbox',)
# Test: Total time: 0:00:21 (0.0654 s / it)
# Averaged stats: class_error: 100.00  loss: 14.4189 (14.1141)  loss_ce: 1.4398 (1.3148)  loss_bbox: 0.4124 (0.5277)  loss_giou: 0.3161 (0.4005)  loss_ce_0: 1.6699 (1.6156)  loss_bbox_0: 0.4339 (0.5880)  loss_giou_0: 0.3826 (0.4442)  loss_ce_1: 1.5544 (1.4290)  loss_bbox_1: 0.3934 (0.5614)  loss_giou_1: 0.3048 (0.4153)  loss_ce_2: 1.4478 (1.3543)  loss_bbox_2: 0.4026 (0.5404)  loss_giou_2: 0.3265 (0.3967)  loss_ce_3: 1.4136 (1.3367)  loss_bbox_3: 0.4187 (0.5315)  loss_giou_3: 0.3012 (0.3981)  loss_ce_4: 1.4200 (1.3321)  loss_bbox_4: 0.4009 (0.5289)  loss_giou_4: 0.3438 (0.3988)  loss_ce_unscaled: 1.4398 (1.3148)  class_error_unscaled: 100.0000 (95.9901)  loss_bbox_unscaled: 0.0825 (0.1055)  loss_giou_unscaled: 0.1581 (0.2003)  cardinality_error_unscaled: 2.0000 (2.2165)  loss_ce_0_unscaled: 1.6699 (1.6156)  loss_bbox_0_unscaled: 0.0868 (0.1176)  loss_giou_0_unscaled: 0.1913 (0.2221)  cardinality_error_0_unscaled: 2.0000 (2.0732)  loss_ce_1_unscaled: 1.5544 (1.4290)  loss_bbox_1_unscaled: 0.0787 (0.1123)  loss_giou_1_unscaled: 0.1524 (0.2077)  cardinality_error_1_unscaled: 2.0000 (2.1433)  loss_ce_2_unscaled: 1.4478 (1.3543)  loss_bbox_2_unscaled: 0.0805 (0.1081)  loss_giou_2_unscaled: 0.1633 (0.1983)  cardinality_error_2_unscaled: 2.0000 (2.1799)  loss_ce_3_unscaled: 1.4136 (1.3367)  loss_bbox_3_unscaled: 0.0837 (0.1063)  loss_giou_3_unscaled: 0.1506 (0.1990)  cardinality_error_3_unscaled: 2.0000 (2.1616)  loss_ce_4_unscaled: 1.4200 (1.3321)  loss_bbox_4_unscaled: 0.0802 (0.1058)  loss_giou_4_unscaled: 0.1719 (0.1994)  cardinality_error_4_unscaled: 2.0000 (2.2256)
# Accumulating evaluation results...
# DONE (t=0.37s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.00:0.75 | area=   all | maxDets=100 ] = 0.060
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.00:0.75 | area= small | maxDets=100 ] = 0.099
#  Average Precision  (AP) @[ IoU=0.00:0.75 | area=medium | maxDets=100 ] = 0.087
#  Average Precision  (AP) @[ IoU=0.00:0.75 | area= large | maxDets=100 ] = 0.056
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area=   all | maxDets=  1 ] = 0.202
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area=   all | maxDets= 10 ] = 0.315
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area=   all | maxDets=100 ] = 0.334
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area= small | maxDets=100 ] = 0.126
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area=medium | maxDets=100 ] = 0.264
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area= large | maxDets=100 ] = 0.346
# Epoch: [40] Total time: 0:00:46 (0.1464 s / it)
# Averaged stats: lr: 0.000010  class_error: 100.00  loss: 11.2813 (11.8819)  loss_ce: 1.4775 (1.3882)  loss_bbox: 0.1270 (0.2457)  loss_giou: 0.1313 (0.2169)  loss_ce_0: 1.7588 (1.7254)  loss_bbox_0: 0.2069 (0.3079)  loss_giou_0: 0.2364 (0.2698)  loss_ce_1: 1.6181 (1.5494)  loss_bbox_1: 0.1786 (0.2680)  loss_giou_1: 0.1886 (0.2372)  loss_ce_2: 1.5304 (1.4543)  loss_bbox_2: 0.1378 (0.2478)  loss_giou_2: 0.1964 (0.2258)  loss_ce_3: 1.4774 (1.4152)  loss_bbox_3: 0.1514 (0.2454)  loss_giou_3: 0.1828 (0.2187)  loss_ce_4: 1.4815 (1.4036)  loss_bbox_4: 0.1214 (0.2454)  loss_giou_4: 0.1631 (0.2172)  loss_ce_unscaled: 1.4775 (1.3882)  class_error_unscaled: 100.0000 (93.4307)  loss_bbox_unscaled: 0.0254 (0.0491)  loss_giou_unscaled: 0.0656 (0.1084)  cardinality_error_unscaled: 2.0000 (2.2830)  loss_ce_0_unscaled: 1.7588 (1.7254)  loss_bbox_0_unscaled: 0.0414 (0.0616)  loss_giou_0_unscaled: 0.1182 (0.1349)  cardinality_error_0_unscaled: 2.0000 (2.7170)  loss_ce_1_unscaled: 1.6181 (1.5494)  loss_bbox_1_unscaled: 0.0357 (0.0536)  loss_giou_1_unscaled: 0.0943 (0.1186)  cardinality_error_1_unscaled: 2.0000 (2.4591)  loss_ce_2_unscaled: 1.5304 (1.4543)  loss_bbox_2_unscaled: 0.0276 (0.0496)  loss_giou_2_unscaled: 0.0982 (0.1129)  cardinality_error_2_unscaled: 2.0000 (2.4214)  loss_ce_3_unscaled: 1.4774 (1.4152)  loss_bbox_3_unscaled: 0.0303 (0.0491)  loss_giou_3_unscaled: 0.0914 (0.1093)  cardinality_error_3_unscaled: 2.0000 (2.3774)  loss_ce_4_unscaled: 1.4815 (1.4036)  loss_bbox_4_unscaled: 0.0243 (0.0491)  loss_giou_4_unscaled: 0.0815 (0.1086)  cardinality_error_4_unscaled: 2.0000 (2.2925)
# hello from ('bbox',)
# Test: Total time: 0:00:21 (0.0642 s / it)
# Averaged stats: class_error: 100.00  loss: 13.7662 (13.2599)  loss_ce: 1.4154 (1.3129)  loss_bbox: 0.2979 (0.4320)  loss_giou: 0.2425 (0.3584)  loss_ce_0: 1.6467 (1.5997)  loss_bbox_0: 0.4276 (0.5093)  loss_giou_0: 0.2775 (0.4074)  loss_ce_1: 1.5034 (1.4239)  loss_bbox_1: 0.3756 (0.4641)  loss_giou_1: 0.2730 (0.3705)  loss_ce_2: 1.4039 (1.3511)  loss_bbox_2: 0.3170 (0.4371)  loss_giou_2: 0.2557 (0.3579)  loss_ce_3: 1.4011 (1.3249)  loss_bbox_3: 0.3265 (0.4388)  loss_giou_3: 0.2550 (0.3594)  loss_ce_4: 1.4158 (1.3249)  loss_bbox_4: 0.3222 (0.4310)  loss_giou_4: 0.2648 (0.3568)  loss_ce_unscaled: 1.4154 (1.3129)  class_error_unscaled: 100.0000 (95.3855)  loss_bbox_unscaled: 0.0596 (0.0864)  loss_giou_unscaled: 0.1212 (0.1792)  cardinality_error_unscaled: 2.0000 (2.2104)  loss_ce_0_unscaled: 1.6467 (1.5997)  loss_bbox_0_unscaled: 0.0855 (0.1019)  loss_giou_0_unscaled: 0.1387 (0.2037)  cardinality_error_0_unscaled: 2.0000 (2.0671)  loss_ce_1_unscaled: 1.5034 (1.4239)  loss_bbox_1_unscaled: 0.0751 (0.0928)  loss_giou_1_unscaled: 0.1365 (0.1852)  cardinality_error_1_unscaled: 2.0000 (2.1890)  loss_ce_2_unscaled: 1.4039 (1.3511)  loss_bbox_2_unscaled: 0.0634 (0.0874)  loss_giou_2_unscaled: 0.1279 (0.1789)  cardinality_error_2_unscaled: 2.0000 (2.2012)  loss_ce_3_unscaled: 1.4011 (1.3249)  loss_bbox_3_unscaled: 0.0653 (0.0878)  loss_giou_3_unscaled: 0.1275 (0.1797)  cardinality_error_3_unscaled: 2.0000 (2.1860)  loss_ce_4_unscaled: 1.4158 (1.3249)  loss_bbox_4_unscaled: 0.0644 (0.0862)  loss_giou_4_unscaled: 0.1324 (0.1784)  cardinality_error_4_unscaled: 2.0000 (2.2165)
# Accumulating evaluation results...
# DONE (t=0.35s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.00:0.75 | area=   all | maxDets=100 ] = 0.055
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.00:0.75 | area= small | maxDets=100 ] = 0.096
#  Average Precision  (AP) @[ IoU=0.00:0.75 | area=medium | maxDets=100 ] = 0.087
#  Average Precision  (AP) @[ IoU=0.00:0.75 | area= large | maxDets=100 ] = 0.052
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area=   all | maxDets=  1 ] = 0.177
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area=   all | maxDets= 10 ] = 0.266
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area=   all | maxDets=100 ] = 0.290
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area= small | maxDets=100 ] = 0.129
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area=medium | maxDets=100 ] = 0.253
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area= large | maxDets=100 ] = 0.296
# Epoch: [41] Total time: 0:00:46 (0.1464 s / it)
# Averaged stats: lr: 0.000010  class_error: 100.00  loss: 10.9900 (11.9036)  loss_ce: 1.2809 (1.3896)  loss_bbox: 0.1694 (0.2402)  loss_giou: 0.1502 (0.2276)  loss_ce_0: 1.6683 (1.7328)  loss_bbox_0: 0.1795 (0.2931)  loss_giou_0: 0.1927 (0.2776)  loss_ce_1: 1.4518 (1.5462)  loss_bbox_1: 0.1706 (0.2564)  loss_giou_1: 0.2069 (0.2473)  loss_ce_2: 1.3223 (1.4558)  loss_bbox_2: 0.1279 (0.2438)  loss_giou_2: 0.1713 (0.2300)  loss_ce_3: 1.2991 (1.4149)  loss_bbox_3: 0.1422 (0.2438)  loss_giou_3: 0.1475 (0.2317)  loss_ce_4: 1.2817 (1.4044)  loss_bbox_4: 0.1492 (0.2404)  loss_giou_4: 0.1419 (0.2279)  loss_ce_unscaled: 1.2809 (1.3896)  class_error_unscaled: 100.0000 (93.3925)  loss_bbox_unscaled: 0.0339 (0.0480)  loss_giou_unscaled: 0.0751 (0.1138)  cardinality_error_unscaled: 2.0000 (2.4025)  loss_ce_0_unscaled: 1.6683 (1.7328)  loss_bbox_0_unscaled: 0.0359 (0.0586)  loss_giou_0_unscaled: 0.0963 (0.1388)  cardinality_error_0_unscaled: 1.0000 (2.6101)  loss_ce_1_unscaled: 1.4518 (1.5462)  loss_bbox_1_unscaled: 0.0341 (0.0513)  loss_giou_1_unscaled: 0.1034 (0.1237)  cardinality_error_1_unscaled: 1.0000 (2.3774)  loss_ce_2_unscaled: 1.3223 (1.4558)  loss_bbox_2_unscaled: 0.0256 (0.0488)  loss_giou_2_unscaled: 0.0856 (0.1150)  cardinality_error_2_unscaled: 2.0000 (2.4623)  loss_ce_3_unscaled: 1.2991 (1.4149)  loss_bbox_3_unscaled: 0.0284 (0.0488)  loss_giou_3_unscaled: 0.0738 (0.1158)  cardinality_error_3_unscaled: 2.0000 (2.4308)  loss_ce_4_unscaled: 1.2817 (1.4044)  loss_bbox_4_unscaled: 0.0298 (0.0481)  loss_giou_4_unscaled: 0.0709 (0.1139)  cardinality_error_4_unscaled: 2.0000 (2.4088)
# hello from ('bbox',)
# Test: Total time: 0:00:21 (0.0650 s / it)
# Averaged stats: class_error: 100.00  loss: 13.4516 (14.1191)  loss_ce: 1.3462 (1.2993)  loss_bbox: 0.2978 (0.5358)  loss_giou: 0.2387 (0.4006)  loss_ce_0: 1.6249 (1.5849)  loss_bbox_0: 0.4341 (0.6254)  loss_giou_0: 0.3371 (0.4510)  loss_ce_1: 1.4577 (1.4009)  loss_bbox_1: 0.3561 (0.5779)  loss_giou_1: 0.2761 (0.4222)  loss_ce_2: 1.4007 (1.3381)  loss_bbox_2: 0.3127 (0.5516)  loss_giou_2: 0.2137 (0.4109)  loss_ce_3: 1.3746 (1.3165)  loss_bbox_3: 0.3062 (0.5498)  loss_giou_3: 0.2223 (0.4042)  loss_ce_4: 1.3692 (1.3152)  loss_bbox_4: 0.3183 (0.5359)  loss_giou_4: 0.2374 (0.3990)  loss_ce_unscaled: 1.3462 (1.2993)  class_error_unscaled: 100.0000 (96.3030)  loss_bbox_unscaled: 0.0596 (0.1072)  loss_giou_unscaled: 0.1193 (0.2003)  cardinality_error_unscaled: 2.0000 (2.2561)  loss_ce_0_unscaled: 1.6249 (1.5849)  loss_bbox_0_unscaled: 0.0868 (0.1251)  loss_giou_0_unscaled: 0.1686 (0.2255)  cardinality_error_0_unscaled: 2.0000 (2.1341)  loss_ce_1_unscaled: 1.4577 (1.4009)  loss_bbox_1_unscaled: 0.0712 (0.1156)  loss_giou_1_unscaled: 0.1381 (0.2111)  cardinality_error_1_unscaled: 2.0000 (2.2652)  loss_ce_2_unscaled: 1.4007 (1.3381)  loss_bbox_2_unscaled: 0.0625 (0.1103)  loss_giou_2_unscaled: 0.1069 (0.2054)  cardinality_error_2_unscaled: 2.0000 (2.2378)  loss_ce_3_unscaled: 1.3746 (1.3165)  loss_bbox_3_unscaled: 0.0612 (0.1100)  loss_giou_3_unscaled: 0.1112 (0.2021)  cardinality_error_3_unscaled: 2.0000 (2.2530)  loss_ce_4_unscaled: 1.3692 (1.3152)  loss_bbox_4_unscaled: 0.0637 (0.1072)  loss_giou_4_unscaled: 0.1187 (0.1995)  cardinality_error_4_unscaled: 2.0000 (2.2591)
# Accumulating evaluation results...
# DONE (t=0.35s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.00:0.75 | area=   all | maxDets=100 ] = 0.052
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.00:0.75 | area= small | maxDets=100 ] = 0.073
#  Average Precision  (AP) @[ IoU=0.00:0.75 | area=medium | maxDets=100 ] = 0.081
#  Average Precision  (AP) @[ IoU=0.00:0.75 | area= large | maxDets=100 ] = 0.048
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area=   all | maxDets=  1 ] = 0.188
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area=   all | maxDets= 10 ] = 0.282
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area=   all | maxDets=100 ] = 0.298
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area= small | maxDets=100 ] = 0.110
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area=medium | maxDets=100 ] = 0.242
#  Average Recall     (AR) @[ IoU=0.00:0.75 | area= large | maxDets=100 ] = 0.308
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-ead07ec7f427> in <module>
#       6 start_time = time.time()
#       7 for epoch in range(epochs):
# ----> 8     train_stats = train_one_epoch(
#       9         model, criterion, data_loader_train, optimizer, device, epoch,
#      10         args.clip_max_norm)
#
# ~/code/posco_objectdetection/detr/engine.py in train_one_epoch(model, criterion, data_loader, optimizer, device, epoch, max_norm)
#      50
#      51         optimizer.zero_grad()
# ---> 52         losses.backward()
#      53         if max_norm > 0:
#      54             torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm)
#
# ~/anaconda3/lib/python3.8/site-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     305                 create_graph=create_graph,
#     306                 inputs=inputs)
# --> 307         torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#     308
#     309     def register_hook(self, hook):
#
# ~/anaconda3/lib/python3.8/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     152         retain_graph = create_graph
#     153
# --> 154     Variable._execution_engine.run_backward(
#     155         tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     156         allow_unreachable=True, accumulate_grad=True)  # allow_unreachable flag
#
# KeyboardInterrupt:

# %% [markdown]
# ## 6. Visualize Results.

# %%
# Load image
im = Image.open('./VOC2007/JPEGImages/000001.jpg')

# mean-std normalize the input image (batch-size: 1)
img = transform(im).unsqueeze(0)

# propagate through the model
model.eval().cpu()
outputs = model(img)

# keep only predictions with 0.01+ confidence
probas = outputs['pred_logits'].softmax(-1)[0, :, :-1]
keep = probas.max(-1).values > 0.1

# convert boxes from [0; 1] to image scales
bboxes_scaled = rescale_bboxes(outputs['pred_boxes'][0, keep], im.size)

plot_results(im, probas[keep], bboxes_scaled)
